# %% [markdown]
# ## Rasa NLU & Rasa Core Tutorial - Building Chatbots

# %%
# How to upload your dataset to colab
from google.colab import files
uploaded = files.upload()

# %%
from IPython.display import Image

# %%
Image("rasa_logo.png")

# %% [markdown]
# ### Rasa NLU & Rasa Core Tutorials
# + Tabula rasa - blank slate
# + Natural Language Understanding tool for understanding what is being said in short pieces of text
# +
# #### Main Idea
# + Intent Classification ===> rasa_nlu
# + Entity Extraction ===> rasa_nlu
# + Dialogue and Actions ===> rasa_core
#
# #### Installing
# - pip install tzlocal==1.5.1
# - pip install rasa_core
#
# #### Adding Backend for NLU
# - pip install rasa_nlu[spacy]
#
# + install a language model for the language you need
# - python -m spacy download en_core_web_md
# - python -m spacy link en_core_web_md en
#
#
# #### Adding Graphiz for Visualization
# apt-get -qq install -y graphviz libgraphviz-dev pkg-config && pip install pygraphviz
#
# #### Easy way Run on Google Colab
# - Python 3.6 and up

# %% [markdown]
# #### CLI Format
# ###### Training and Building the Model
#     - python -m rasa_nlu.train -c nlu_config.yml --data data/nlu_data.md -o models --fixed_model_name nlu --project current --verbose
# ###### Training the dialogue model
#     - python -m rasa_core.train -d domain.yml -s data/stories.md -o models/current/dialogue --epochs 200
# ###### Runing our bots
#     - python -m rasa_core.run -d models/current/dialogue -u models/current/nlu

# %% [markdown]
# # Outline
# Installation
# Writing Stories
# Defining a Domain
# Training your Dialogue Model
# Starting up the bot
# Talking to the bot (no NLU)
# Part 2: Add natural language understanding
# Installing NLU
# Language Understanding
# Train the Rasa NLU Model
# Starting up the bot (with NLU)
# Talking to the Bot (with NLU)
# Pro Tip: Visualising the Training Data

# %% [markdown]
# #### Practice on the Colab
# https://colab.research.google.com/github/RasaHQ/rasa_core/blob/master/getting_started.ipynb

# %%
# Installation
# !pip install rasa_core;

import logging, io, json, warnings
logging.basicConfig(level="INFO")
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: rasa_core in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (0.13.7)
# Requirement already satisfied: python-telegram-bot~=11.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (11.1.0)
# Requirement already satisfied: scipy~=1.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.2.1)
# Requirement already satisfied: flask~=1.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: flask-cors~=3.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (3.0.7)
# Requirement already satisfied: colorclass~=2.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2.2.0)
# Requirement already satisfied: mattermostwrapper~=2.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2.1)
# Requirement already satisfied: questionary>=1.0.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: keras-preprocessing==1.0.5 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.0.5)
# Requirement already satisfied: flask-jwt-simple~=0.0.3 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.0.3)
# Requirement already satisfied: twilio~=6.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (6.26.0)
# Requirement already satisfied: tensorflow~=1.12.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.12.0)
# Requirement already satisfied: rasa-core-sdk~=0.12.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.12.2)
# Requirement already satisfied: tqdm~=4.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (4.29.1)
# Requirement already satisfied: keras-applications==1.0.6 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.0.6)
# Requirement already satisfied: slackclient~=1.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.3.1)
# Requirement already satisfied: terminaltables~=3.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (3.1.0)
# Requirement already satisfied: fbmessenger~=5.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (5.5.0)
# Requirement already satisfied: rasa-nlu~=0.14.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.14.6)
# Requirement already satisfied: rocketchat-API~=0.6.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.6.28)
# Requirement already satisfied: pika~=0.12.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.12.0)
# Requirement already satisfied: jsonpickle~=1.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.0)
# Requirement already satisfied: typing~=3.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (3.6.6)
# Requirement already satisfied: redis~=2.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2.10.6)
# Requirement already satisfied: gevent~=1.4 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.4.0)
# Requirement already satisfied: apscheduler~=3.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (3.5.1)
# Requirement already satisfied: coloredlogs~=10.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (10.0)
# Requirement already satisfied: webexteamssdk~=1.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.1.1)
# Requirement already satisfied: fakeredis~=0.10.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.10.3)
# Requirement already satisfied: ruamel.yaml~=0.15.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.15.85)
# Requirement already satisfied: pymongo~=3.7 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (3.7.2)
# Requirement already satisfied: pykwalify~=1.7.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.7.0)
# Requirement already satisfied: numpy~=1.16 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.16.2)
# Requirement already satisfied: packaging~=18.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (18.0)
# Requirement already satisfied: scikit-learn~=0.20.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (0.20.2)
# Requirement already satisfied: pydot~=1.4 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.4.1)
# Requirement already satisfied: colorhash~=1.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (1.0.2)
# Requirement already satisfied: pytz~=2018.9 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2018.9)
# Requirement already satisfied: python-dateutil~=2.7 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2.7.5)
# Requirement already satisfied: python-socketio~=3.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (3.1.2)
# Requirement already satisfied: requests~=2.20 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2.21.0)
# Requirement already satisfied: jsonschema~=2.6 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2.6.0)
# Requirement already satisfied: networkx~=2.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa_core) (2.2)
# Requirement already satisfied: cryptography in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from python-telegram-bot~=11.0->rasa_core) (2.6.1)
# Requirement already satisfied: certifi in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from python-telegram-bot~=11.0->rasa_core) (2019.3.9)
# Requirement already satisfied: future>=0.16.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from python-telegram-bot~=11.0->rasa_core) (0.17.1)
# Requirement already satisfied: click>=5.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from flask~=1.0->rasa_core) (7.0)
# Requirement already satisfied: Jinja2>=2.10 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from flask~=1.0->rasa_core) (2.10)
# Requirement already satisfied: Werkzeug>=0.14 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from flask~=1.0->rasa_core) (0.15.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from flask~=1.0->rasa_core) (1.1.0)
# Requirement already satisfied: Six in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from flask-cors~=3.0->rasa_core) (1.11.0)
# Requirement already satisfied: prompt-toolkit~=2.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from questionary>=1.0.1->rasa_core) (2.0.9)
# Requirement already satisfied: PyJWT in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from flask-jwt-simple~=0.0.3->rasa_core) (1.7.1)
# Requirement already satisfied: pysocks; python_version >= "3.0" in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from twilio~=6.0->rasa_core) (1.6.8)
# Requirement already satisfied: wheel>=0.26 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (0.33.1)
# Requirement already satisfied: absl-py>=0.1.6 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (0.7.1)
# Requirement already satisfied: tensorboard<1.13.0,>=1.12.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (1.12.2)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (1.19.0)
# Requirement already satisfied: astor>=0.6.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (0.7.1)
# Requirement already satisfied: gast>=0.2.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (0.2.2)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorflow~=1.12.0->rasa_core) (3.7.1)
# Requirement already satisfied: ConfigArgParse~=0.13.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa-core-sdk~=0.12.1->rasa_core) (0.13.0)
# Requirement already satisfied: h5py in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from keras-applications==1.0.6->rasa_core) (2.7.1)
# Requirement already satisfied: websocket-client<0.55.0,>=0.35 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from slackclient~=1.0->rasa_core) (0.54.0)
# Requirement already satisfied: klein~=17.10 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa-nlu~=0.14.0->rasa_core) (17.10.0)
# Requirement already satisfied: cloudpickle~=0.6.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa-nlu~=0.14.0->rasa_core) (0.6.1)
# Requirement already satisfied: simplejson~=3.13 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa-nlu~=0.14.0->rasa_core) (3.16.0)
# Requirement already satisfied: boto3~=1.5 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa-nlu~=0.14.0->rasa_core) (1.9.127)
# Requirement already satisfied: matplotlib~=2.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from rasa-nlu~=0.14.0->rasa_core) (2.2.4)
# Requirement already satisfied: cffi>=1.11.5; sys_platform == "win32" and platform_python_implementation == "CPython" in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from gevent~=1.4->rasa_core) (1.12.2)
# Requirement already satisfied: greenlet>=0.4.14; platform_python_implementation == "CPython" in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from gevent~=1.4->rasa_core) (0.4.15)
# Requirement already satisfied: setuptools>=0.7 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from apscheduler~=3.0->rasa_core) (40.8.0)
# Requirement already satisfied: tzlocal>=1.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from apscheduler~=3.0->rasa_core) (1.5.1)
# Requirement already satisfied: humanfriendly>=4.7 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from coloredlogs~=10.0->rasa_core) (4.18)
# Requirement already satisfied: colorama; sys_platform == "win32" in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from coloredlogs~=10.0->rasa_core) (0.4.1)
# Requirement already satisfied: requests-toolbelt in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from webexteamssdk~=1.0->rasa_core) (0.9.1)
# Requirement already satisfied: PyYAML>=3.11 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from pykwalify~=1.7.0->rasa_core) (5.1)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from pykwalify~=1.7.0->rasa_core) (0.6.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from packaging~=18.0->rasa_core) (2.3.1)
# Requirement already satisfied: python-engineio>=3.2.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from python-socketio~=3.0->rasa_core) (3.5.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from requests~=2.20->rasa_core) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from requests~=2.20->rasa_core) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from requests~=2.20->rasa_core) (1.24.1)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from networkx~=2.2->rasa_core) (4.4.0)
# Requirement already satisfied: asn1crypto>=0.21.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from cryptography->python-telegram-bot~=11.0->rasa_core) (0.24.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from Jinja2>=2.10->flask~=1.0->rasa_core) (1.1.1)
# Requirement already satisfied: wcwidth in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from prompt-toolkit~=2.0->questionary>=1.0.1->rasa_core) (0.1.7)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow~=1.12.0->rasa_core) (3.1)
# Requirement already satisfied: Twisted>=15.5 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (18.9.0)
# Requirement already satisfied: incremental in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (17.5.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.9.4)
# Requirement already satisfied: botocore<1.13.0,>=1.12.127 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (1.12.127)
# Requirement already satisfied: s3transfer<0.3.0,>=0.2.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from matplotlib~=2.0->rasa-nlu~=0.14.0->rasa_core) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from matplotlib~=2.0->rasa-nlu~=0.14.0->rasa_core) (1.0.1)
# Requirement already satisfied: pycparser in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from cffi>=1.11.5; sys_platform == "win32" and platform_python_implementation == "CPython"->gevent~=1.4->rasa_core) (2.19)
# Requirement already satisfied: pyreadline; sys_platform == "win32" in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from humanfriendly>=4.7->coloredlogs~=10.0->rasa_core) (2.1)
# Requirement already satisfied: PyHamcrest>=1.9.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (1.9.0)
# Requirement already satisfied: hyperlink>=17.1.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (18.0.0)
# Requirement already satisfied: Automat>=0.3.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (0.7.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (19.1.0)
# Requirement already satisfied: zope.interface>=4.4.2 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (4.6.0)
# Requirement already satisfied: constantly>=15.1 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from Twisted>=15.5->klein~=17.10->rasa-nlu~=0.14.0->rasa_core) (15.1.0)
# Requirement already satisfied: docutils>=0.10 in c:\users\kulkarni\anaconda3\envs\rasa\lib\site-packages (from botocore<1.13.0,>=1.12.127->boto3~=1.5->rasa-nlu~=0.14.0->rasa_core) (0.14)

# %% [markdown]
# #### Writing A Story

# %% [markdown]
# ### Story Structure
#   - starts stories ==> ##
#   -  intent/entities of the message you are sending ==> *
#   -  actions that the bot will do or take eg utter_greet,utter_location,API_function
#       with dash  -

# %%
Image('sample_chatbot.png')

# %%
stories_md = """
## happy path               <!-- name of the story - just for debugging -->
* greet              
  - utter_greet
* mood_great               <!-- user utterance, in format intent[entities] -->
  - utter_happy
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_goodbye
  
  
## sad path 1               <!-- this is already the start of the next story -->
* greet
  - utter_greet             <!-- action the bot should execute -->
* mood_unhappy
  - utter_cheer_up
  - utter_did_that_help
* mood_affirm
  - utter_happy

## good purchase path               <!-- name of the story - for making purchase-->
* greet              
  - utter_greet
* mood_great               <!-- user utterance, in format intent[entities] -->
  - utter_happy
* mood_affirm
  - utter_happy
* purchase                  <! -- user intention to purchase things --->
  - utter_purchase  
* purchase_affirm           <!-- user utterance, in format intent[entities] -->
  - utter_purchase
* purchase_affirm
  - utter_price
* mood_affirm
  - utter_goodbye
  
## good purchase path2
* greet              
  - utter_greet
* inform                    <!-- user utterance, in format intent[entities] -->
  - utter_ask_item
  - utter_show_item
  - utter_did_that_help
* goodbye
    - utter_goodbye

## no purchase path               <!-- name of the story - for making purchase-->
* greet              
  - utter_greet
* mood_great               <!-- user utterance, in format intent[entities] -->
  - utter_happy
* mood_affirm
  - utter_happy
* purchase                  <! -- user intention to purchase things --->
  - utter_purchase  
* purchase_deny           <!-- user utterance, in format intent[entities] -->
  - utter_purchase
* purchase_deny
  - utter_ask_item
* mood_affirm
  - utter_goodbye
  
  
## get weather of location
* greet
  - utter_greet
* mood_great               <!-- user utterance, in format intent[entities] -->
  - utter_happy
* inform
  - utter_ask_location
* inform{"location": "Paris"}
  - utter_ask_location
* goodbye
    - utter_goodbye
    - export
    
## get weather of location
* greet
    - utter_greet
* inform[location=London]
    - utter_ask_location
* goodbye
    - utter_goodbye
    - export
  
  
## strange user
* mood_affirm
  - utter_happy
* mood_affirm
  - utter_unclear

## say goodbye
* goodbye
  - utter_goodbye

"""

# %store stories_md > my_stories.md
# Out:
# Writing 'stories_md' (str) to file 'my_stories.md'.

# %% [markdown]
# ### Defining the Domain Universe/Environment
# + Where(universe or environment) your bot lives
#  - - intents : what you expect users to say,their intentions
#  - - action : what your bot is supposed to do(list them eg utter_greet,custom actions)
#  - - template :
#
# + Stories

# %%
Image('summaryofdomain_rasa_nlu.png')

# %%
domain_yml = """
intents:
  - greet
  - goodbye
  - mood_affirm
  - mood_deny
  - mood_great
  - mood_unhappy
  - purchase
  - purchase_affirm
  - purchase_deny
  - inform
  - weather
  
entities:
 - location
 - money
 
slots:
 location:
   type: text


actions:
- utter_greet
- utter_cheer_up
- utter_purchase
- utter_price
- utter_did_that_help
- utter_ask_item
- utter_show_item
- utter_happy
- utter_goodbye
- utter_unclear
- utter_ask_location

templates:
  utter_greet:
  - text: "Hey! How are you?"
  - text: "Hi How are you?"
  - text: "What's up"
  - text: "Bonjour"

  utter_cheer_up:
  - text: "Stay motivated,all is well"
  - text: "Here is something to make you happy"
  - text: "Here is something to cheer you up:"
    image: "https://i.imgur.com/nGF1K8f.jpg"

  utter_did_that_help:
  - text: "Did that help you?"

  utter_unclear:
  - text: "I am not sure what you are aiming for."
  - text: "How do you mean? Can you clarify "
  - text: "Not quite sure what you want. "
  
  utter_happy:
  - text: "Great carry on!" 
  
  utter_purchase:
  - text: 'What item do you want to buy?'
  - text: 'Here are some recommended products'
  - text: 'You want to buy this?'
  - text: 'We only have this?'
  - text: 'Can you give me the specs ?'
  
  utter_ask_item:
  - text: 'What item do you want to buy?'
  - text: 'How many do you want to buy?'
  - text: 'Which type?'

  utter_show_item:
  - text: "Here are some suggestions."
  - text: "Check this one out."
  - text: "We only have this product"
  - text: "Sending sample picture"
    
  utter_price:
  - text: "It will cost you this much"
  - text: "The price is 100"
  - text: "You will pay"
  - text: "Here is the bill"
  - text: "The total cost is 2000, you can pay with your credit card."

  utter_ask_location:
  - text:'In what location?'
  - text:'In which place?'
  - text:'Where precisely?'

  utter_goodbye:
  - text: "Bye"
  - text: "Talk to you later"
  - text: "Cu"
  - text: "Aurevoir"
  - text: "A bientot "
  - text: "goodbye"
  - text: "have a nice day"
  - text: "see you around"
  - text: "bye bye"
  - text: "See you later"
  
"""

# %store domain_yml > my_domain.yml
# Out:
# Writing 'domain_yml' (str) to file 'my_domain.yml'.

# %% [markdown]
# #### Training your Dialogue Model
# + rasa_core
# + Using Keras
# + Install keras + tensorflow backend

# %%
# Load the packages without using fallbackpolicy
from rasa_core.policies.keras_policy import KerasPolicy
from rasa_core.agent import Agent
# Out:
# INFO:apscheduler.scheduler:Scheduler started

# %%
# Set the Agent
agent = Agent('my_domain.yml', policies=[KerasPolicy()])

# %%
# loading our neatly defined training dialogues
training_data = agent.load_data('my_stories.md')
agent.train(
        training_data
)
# Out:
# WARNING:rasa_core.training.dsl:Found unknown intent 'purchase                  <! -- user intention to purchase things --->' on line 29. Please, make sure that all intents are listed in your domain yaml.
# WARNING:rasa_core.training.dsl:Found unknown intent 'purchase                  <! -- user intention to purchase things --->' on line 57. Please, make sure that all intents are listed in your domain yaml.
# WARNING:rasa_core.training.dsl:Found unknown intent 'inform[location=London]' on line 83. Please, make sure that all intents are listed in your domain yaml.
# Processed Story Blocks: 100%|█████| 9/9 [00:00<00:00, 428.54it/s, # trackers=1]
# Processed Story Blocks: 100%|█████| 9/9 [00:00<00:00, 176.46it/s, # trackers=9]
# Processed Story Blocks: 100%|████| 9/9 [00:00<00:00, 108.43it/s, # trackers=14]
# Processed Story Blocks: 100%|████| 9/9 [00:00<00:00, 116.88it/s, # trackers=12]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (None, 5, 32)             0
# _________________________________________________________________
# lstm (LSTM)                  (None, 32)                8320
# _________________________________________________________________
# dense (Dense)                (None, 18)                594
# _________________________________________________________________
# activation (Activation)      (None, 18)                0
# =================================================================
# Total params: 8,914
# Trainable params: 8,914
# Non-trainable params: 0
# _________________________________________________________________
# INFO:rasa_core.policies.keras_policy:Fitting model with 253 total samples and a validation split of 0.1
# Epoch 1/100
# 253/253 [==============================] - ETA: 24s - loss: 2.9470 - acc: 0.0000e+ - ETA: 3s - loss: 2.9294 - acc: 0.0312     - 4s 15ms/step - loss: 2.8942 - acc: 0.0553
# Epoch 2/100
# 253/253 [==============================] - ETA: 0s - loss: 2.8073 - acc: 0.156 - ETA: 0s - loss: 2.7941 - acc: 0.209 - 0s 340us/step - loss: 2.7848 - acc: 0.2372
# Epoch 3/100
# 253/253 [==============================] - ETA: 0s - loss: 2.7139 - acc: 0.281 - ETA: 0s - loss: 2.6932 - acc: 0.370 - 0s 316us/step - loss: 2.6746 - acc: 0.3953
# Epoch 4/100
# 253/253 [==============================] - ETA: 0s - loss: 2.6305 - acc: 0.312 - 0s 217us/step - loss: 2.5465 - acc: 0.4229
# Epoch 5/100
# 253/253 [==============================] - ETA: 0s - loss: 2.4672 - acc: 0.375 - 0s 233us/step - loss: 2.3970 - acc: 0.4308
# Epoch 6/100
# 253/253 [==============================] - ETA: 0s - loss: 2.2963 - acc: 0.375 - 0s 233us/step - loss: 2.2308 - acc: 0.4348
# Epoch 7/100
# 253/253 [==============================] - ETA: 0s - loss: 2.2551 - acc: 0.375 - 0s 261us/step - loss: 2.1236 - acc: 0.4348
# Epoch 8/100
# 253/253 [==============================] - ETA: 0s - loss: 2.1893 - acc: 0.375 - ETA: 0s - loss: 2.1236 - acc: 0.410 - 0s 293us/step - loss: 2.0792 - acc: 0.4348
# Epoch 9/100
# 253/253 [==============================] - ETA: 0s - loss: 2.1868 - acc: 0.375 - 0s 253us/step - loss: 2.0109 - acc: 0.4348
# Epoch 10/100
100
# 253/253 [==============================] - ETA: 0s - loss: 0.4902 - acc: 0.875 - 0s 217us/step - loss: 0.4895 - acc: 0.9091
# Epoch 91/100
# 253/253 [==============================] - ETA: 0s - loss: 0.5392 - acc: 0.843 - 0s 209us/step - loss: 0.5126 - acc: 0.8893
# Epoch 92/100
# 253/253 [==============================] - ETA: 0s - loss: 0.4661 - acc: 0.875 - 0s 206us/step - loss: 0.4755 - acc: 0.9209
# Epoch 93/100
# 253/253 [==============================] - ETA: 0s - loss: 0.5379 - acc: 0.875 - 0s 186us/step - loss: 0.4909 - acc: 0.9051
# Epoch 94/100
# 253/253 [==============================] - ETA: 0s - loss: 0.4675 - acc: 0.937 - 0s 209us/step - loss: 0.4619 - acc: 0.8735
# Epoch 95/100
# 253/253 [==============================] - ETA: 0s - loss: 0.4913 - acc: 0.937 - 0s 217us/step - loss: 0.4686 - acc: 0.9130
# Epoch 96/100
# 253/253 [==============================] - ETA: 0s - loss: 0.5036 - acc: 0.875 - 0s 202us/step - loss: 0.4472 - acc: 0.9249
# Epoch 97/100
# 253/253 [==============================] - ETA: 0s - loss: 0.4853 - acc: 0.843 - 0s 241us/step - loss: 0.4581 - acc: 0.9091
# Epoch 98/100
# 253/253 [==============================] - ETA: 0s - loss: 0.4721 - acc: 0.875 - 0s 178us/step - loss: 0.4345 - acc: 0.9170
# Epoch 99/100
# 253/253 [==============================] - ETA: 0s - loss: 0.4855 - acc: 0.875 - 0s 194us/step - loss: 0.4489 - acc: 0.9091
# Epoch 100/100
# 253/253 [==============================] - ETA: 0s - loss: 0.4332 - acc: 0.937 - 0s 190us/step - loss: 0.4382 - acc: 0.9209
# INFO:rasa_core.policies.keras_policy:Done fitting keras policy model

# %%
# Saving Our Dialogue Models
agent.persist('models/dialogue')
# Out:
# INFO:rasa_core.agent:Persisted model to 'D:\Yogesh\ToDos\Projects\Teaching\Teaching_DataScience\Jupyter\purchasebot\models\dialogue'

# %% [markdown]
# #### Starting up the bot
# + rasa_core
# + agent
# + dialogue model

# %% [markdown]
# The default 'Loader' for 'load(stream)' without further arguments can be unsafe.
# Use 'load(stream, Loader=ruamel.yaml.Loader)' explicitly if that is OK.
# Alternatively include the following in your code:
#
#   import warnings
#   warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# In most other cases you should consider using 'safe_load(stream)'
#   data = yaml.load(stream)

# %%
# Load Dialogue model into agent
from rasa_core.agent import Agent
agent = Agent.load('models/dialogue')

# With NLU Trained data
# agent = Agent.load('models/dialogue', interpreter=model_directory)

# %% [markdown]
# #### Practising or Talking to the bot

# %%
print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_message(a)
    for response in responses:
        print(response["text"])
# Out:
# Your bot is ready to talk! Type your messages here or send 'stop'
# Hi
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Aurevoir
# I want to buy phone
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Cool,what can I help you with?
# Price
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# A bientot
# stop

# %% [markdown]
# ## Training Our Bot with Rasa NLU

# %% [markdown]
# ### Natural Language Understanding and Intent Classification

# %%
# Loading our Packages
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# %% [markdown]
# #### How our dataset can look like
# + Describes what the messages mean/intention
# + json
# + md
# + yml

# %%
## intent:intentname
- examples
- examples
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2e3923f9625d> in <module>
#       1 ## intent:intentname
# ----> 2 - examples
#       3 - examples
#
# NameError: name 'examples' is not defined

# %%
# Data Set
nludataset_md = """
## intent:greet
- hey
- hello
- hi
- hello there
- good morning
- good evening
- moin
- hey there
- let's go
- hey dude
- goodmorning
- goodevening
- good afternoon

## intent:goodbye
- cu
- good by
- cee you later
- good night
- good afternoon
- bye
- goodbye
- have a nice day
- see you around
- bye bye
- see you later

## intent:mood_affirm
- yes
- indeed
- of course
- that sounds good
- correct

## intent:mood_deny
- no
- never
- I don't think so
- don't like that
- no way
- not really

## intent:mood_great
- perfect
- very good
- great
- amazing
- feeling like a king
- wonderful
- I am feeling very good
- I am great
- I am amazing
- I am going to save the world
- super
- extremely good
- so so perfect
- so good
- so perfect

## intent:mood_unhappy
- my day was horrible
- I am sad
- I don't feel very well
- I am disappointed
- super sad
- I'm so sad
- sad
- very sad
- unhappy
- bad
- very bad
- awful
- terrible
- not so good
- not very good
- extremly sad
- so saad
- so sad

## intent:purchase
- I need to buy IPhone
- I want to purchase some items
- What product is that?
- You need this watch.
- How much that it cost?
- He bought this house for $2000
- She is selling it
- I need to buy another
- Can you make a request for the product
- How much?
- This is so expensive
- It was very cheap
- He is buying 
- You ordered for this
- buy
- sell
- pay
- purchase
- what is the price
- Tell me the price
- Show me the product

## intent:purchase_affirm
- yes
- yes I need to buy it
- indeed I want to buy
- of course
- that sounds good
- correct
- I will take it

## intent:purchase_deny
- no I don't want it
- never
- I don't think so
- don't like that
- no way 
- not really
- no


## intent:inform
- I need to buy IPhone
- I want to purchase some items
- What product is that?

## intent:weather
- I wonder what is the weather in Vilnius right now?
- what is the weather?
- Tell me the weather
- Is the weather nice in Barcelona today
- I am going to London today and I wonder what is the weather out there?
- Show me the weather in Dublin, please
- Tell me the weather in Vilnius

"""

# %store nludataset_md > nludataset.md
# Out:
# Writing 'nludataset_md' (str) to file 'nludataset.md'.

# %%
# Loading Dataset
# Dataset can be in json or md
training_data = load_data('nludataset.md')
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nludataset.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 113 (11 distinct intents)
# 	- Found intents: 'mood_deny', 'goodbye', 'purchase_deny', 'weather', 'purchase', 'mood_great', 'mood_affirm', 'mood_unhappy', 'purchase_affirm', 'greet', 'inform'
# 	- entity examples: 0 (0 distinct entities)
# 	- found entities:

# %%
# !apt-get -qq install -y graphviz libgraphviz-dev pkg-config && pip install pygraphviz;
# !pip install rasa_nlu[spacy];
# !python -m spacy download en;

# %% [markdown]
# #### Configuration File
# + spacy as backend
# + mitie as backend

# %%
# Load the Rasa_nlu Packages
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer

# %% [markdown]
# #### Load and Configure our Backend with spaCy

# %%
training_data = load_data('nludataset.md')
pipeline = [{"name": "nlp_spacy"}, 
            {"name": "tokenizer_spacy"}, 
            {"name": "intent_featurizer_spacy"},  
            {"name": "intent_classifier_sklearn"}]
# Out:
# INFO:rasa_nlu.training_data.loading:Training data format of nludataset.md is md
# INFO:rasa_nlu.training_data.training_data:Training data stats:
# 	- intent examples: 113 (11 distinct intents)
# 	- Found intents: 'mood_deny', 'goodbye', 'purchase_deny', 'weather', 'purchase', 'mood_great', 'mood_affirm', 'mood_unhappy', 'purchase_affirm', 'greet', 'inform'
# 	- entity examples: 0 (0 distinct entities)
# 	- found entities:

# %%
trainer = Trainer(RasaNLUModelConfig({"pipeline": pipeline}))
interpreter = trainer.train(training_data)
model_directory = trainer.persist('./projects/default/')
# Out:
# INFO:rasa_nlu.utils.spacy_utils:Trying to load spacy model with name 'en'
# INFO:rasa_nlu.components:Added 'nlp_spacy' to component cache. Key 'nlp_spacy-en'.
# INFO:rasa_nlu.model:Starting to train component nlp_spacy
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component tokenizer_spacy
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component intent_featurizer_spacy
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Starting to train component intent_classifier_sklearn
# Fitting 2 folds for each of 6 candidates, totalling 12 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.2s finished
# INFO:rasa_nlu.model:Finished training component.
# INFO:rasa_nlu.model:Successfully saved model into 'D:\Yogesh\ToDos\Projects\Teaching\Teaching_DataScience\Jupyter\purchasebot\projects\default\default\model_20190520-165134'

# %%
from rasa_core.agent import Agent
agent = Agent.load('models/dialogue', interpreter=model_directory)
# Out:
# WARNING:rasa_core.agent:Passing a value for interpreter to an agent where the value is not an interpreter is deprecated. Construct the interpreter, beforepassing it to the agent, e.g. `interpreter = NaturalLanguageInterpreter.create(nlu)`.
# INFO:rasa_nlu.components:Added 'nlp_spacy' to component cache. Key 'nlp_spacy-en'.

# %% [markdown]
#  #### Lets Chat

# %%
print("Your bot is ready to talk! Type your messages here or send 'stop'")
while True:
    a = input()
    if a == 'stop':
        break
    responses = agent.handle_message(a)
    for response in responses:
        print(response["text"])
# Out:
# Your bot is ready to talk! Type your messages here or send 'stop'
# Hi
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# What's up
# I want to buy a Phone
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# text:'In what location?'
# Paris
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# have a nice day
# Hi
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Hey! How are you?
# Good
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Cool,what can I help you with?
# I wish to buy a phone
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# text:'Where precisely?'
# Paris
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# have a nice day
# why
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# See you later
# no
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# A bientot
# Phone
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Cu
# No
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# Cu
# I want to buy a phone
# WARNING:rasa_core.agent:Passing a text to `agent.handle_message(...)` is deprecated. Rather use `agent.handle_text(...)`.
# A bientot

# %%
import platform
platform.python_version()

# %% [markdown]
# ## Intent Classification With Rasa_nlu

# %%
from rasa_nlu.training_data import load_data
from rasa_nlu.config import RasaNLUModelConfig
from rasa_nlu.model import Trainer
from rasa_nlu import config

# %%
# Loading our Dataset
# Dataset can be in json,md
training_data = load_data('nludataset.md')

# %%
# Setting Up our Training Configuration with Spacy as Backend
trainer = Trainer(config.load("config_spacy.yml"))

# %%
# Model Building
model_directory = trainer.persist('./projects/default/')

# %%
# Prediction
from rasa_nlu.model import Metadata, Interpreter

# %%
# where `model_directory points to the folder the model is persisted in
interpreter = Interpreter.load(model_directory)

# %%
# Predicting
interpreter.parse(u"I am looking for an African spot to eat")

# %%
interpreter.parse(u"Good morning everyone")

# %% [markdown]
# ### Rasa GUI
# ##### Online
# + https://rasahq.github.io/rasa-nlu-trainer/
# ##### Offline
# + npm i -g rasa-nlu-trainer

# %% [markdown]
# #### Building your dataset
# + rasa-nlu-trainer gui
#  - - Requirement
#   - - - nodejs npm + browser(Chrome)
#   - - - - + npm install -g rasa-nlu-trainer
#   - - - fileformat in json
# + DIY

# %% [markdown]
# #### Basic Format of the Dataset.Json
# ###### Most Basic Format
# {
#   "rasa_nlu_data": {}
# }
#
#
# #### Simple Format
# {
#   "rasa_nlu_data": {
#     "common_examples": []
#   }
# }

# %% [markdown]
# #### Evaluating Model

# %%
# Import from rasa_nlu
from rasa_nlu.evaluate import run_evaluation

run_evaluation("sampledatasetrasa.json", model_directory)

# %% [markdown]
# #### Adding Custom API functions

# %%
from rasa_core.actions import Action
from rasa_core.events import SlotSet

import requests
# from __future__ import absolute_import
# from __future__ import division
# from __future__ import unicode_literals

class ApiAction(Action):
    def name(self):
        return "action_retrieve_image"

    def run(self, dispatcher, tracker, domain):
        dispatcher.utter_message("looking for a good img")
        url = "https://picsum.photos/200/300/?random"
        return [SlotSet("img_api_response", url)]
    
class ActionWeather(Action):
    def name(self):
        return 'action_weather'

    def run(self, dispatcher, tracker, domain):
        from apixu.client import ApixuClient
        api_key = '...' #your apixu key
        client = ApixuClient(api_key)
        
        loc = tracker.get_slot('location')
        current = client.getCurrentWeather(q=loc)
        
        country = current['location']['country']
        city = current['location']['name']
        condition = current['current']['condition']['text']
        temperature_c = current['current']['temp_c']
        humidity = current['current']['humidity']
        wind_mph = current['current']['wind_mph']

        response = """It is currently {} in {} at the moment. The temperature is {} degrees, the humidity is {}% and the wind speed is {} mph.""".format(condition, city, temperature_c, humidity, wind_mph)
        dispatcher.utter_message(response)
        return [SlotSet('location',loc)]

# %% [markdown]
# ### Visualizing The Dialogue

# %%
from rasa_core.agent import Agent
from IPython.display import Image

agent = Agent.load('models/dialogue')
agent.visualize("stories.md", "story_graph.png", max_history=2)
Image(filename="story_graph.png")
# Out:
# /usr/local/lib/python3.6/dist-packages/pykwalify/core.py:99: UnsafeLoaderWarning:
# The default 'Loader' for 'load(stream)' without further arguments can be unsafe.
# Use 'load(stream, Loader=ruamel.yaml.Loader)' explicitly if that is OK.
# Alternatively include the following in your code:
#
#   import warnings
#   warnings.simplefilter('ignore', ruamel.yaml.error.UnsafeLoaderWarning)
#
# In most other cases you should consider using 'safe_load(stream)'
#   data = yaml.load(stream)
# Processed Story Blocks: 100%|██████████| 5/5 [00:00<00:00, 175.29it/s, # trackers=1]

# %%
### Jesse JCharis
# J-Security
# Jesus Saves @JCharisTech
