# %%
# Install required packages.
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.9.0+cu102.html
# !pip install -q torch-geometric
# !pip install -q captum

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
# Out:
#      |████████████████████████████████| 11.9MB 2.2MB/s
#      |████████████████████████████████| 24.3MB 81.4MB/s
#      |████████████████████████████████| 194kB 4.3MB/s
#      |████████████████████████████████| 235kB 7.7MB/s
#      |████████████████████████████████| 2.2MB 7.8MB/s
#      |████████████████████████████████| 51kB 5.6MB/s
#   Building wheel for torch-geometric (setup.py) ... done
#      |████████████████████████████████| 4.4MB 4.2MB/s

# %% [markdown]
# # Explaining GNN Model Predictions using Captum
#
# In this tutorial we demonstrate how to apply feature attribution methods to graphs. Specifically, we try to find the most important edges for each instance prediction.
#
# We use the Mutagenicity dataset from [TUDatasets](https://chrsmrrs.github.io/datasets/). This dataset consists of 4337 molecule graphs where the task is to predict the molecule mutagenicity.

# %% [markdown]
# ## Loading the dataset
#
# We load the dataset and use 10% of the data as the test split.

# %%
from torch_geometric.data import DataLoader
from torch_geometric.datasets import TUDataset

path = '.'
dataset = TUDataset(path, name='Mutagenicity').shuffle()
test_dataset = dataset[:len(dataset) // 10]
train_dataset = dataset[len(dataset) // 10:]
test_loader = DataLoader(test_dataset, batch_size=128)
train_loader = DataLoader(train_dataset, batch_size=128)
# Out:
# Downloading https://www.chrsmrrs.com/graphkerneldatasets/Mutagenicity.zip
# Extracting ./Mutagenicity/Mutagenicity.zip
# Processing...
# Done!

# %% [markdown]
# ## Visualizing the data
#
# We define some utility functions for visualizing the molecules and draw a random molecule.

# %%
import networkx as nx
import numpy as np

from torch_geometric.utils import to_networkx


def draw_molecule(g, edge_mask=None, draw_edge_labels=False):
    g = g.copy().to_undirected()
    node_labels = {}
    for u, data in g.nodes(data=True):
        node_labels[u] = data['name']
    pos = nx.planar_layout(g)
    pos = nx.spring_layout(g, pos=pos)
    if edge_mask is None:
        edge_color = 'black'
        widths = None
    else:
        edge_color = [edge_mask[(u, v)] for u, v in g.edges()]
        widths = [x * 10 for x in edge_color]
    nx.draw(g, pos=pos, labels=node_labels, width=widths,
            edge_color=edge_color, edge_cmap=plt.cm.Blues,
            node_color='azure')
    
    if draw_edge_labels and edge_mask is not None:
        edge_labels = {k: ('%.2f' % v) for k, v in edge_mask.items()}    
        nx.draw_networkx_edge_labels(g, pos, edge_labels=edge_labels,
                                    font_color='red')
    plt.show()


def to_molecule(data):
    ATOM_MAP = ['C', 'O', 'Cl', 'H', 'N', 'F',
                'Br', 'S', 'P', 'I', 'Na', 'K', 'Li', 'Ca']
    g = to_networkx(data, node_attrs=['x'])
    for u, data in g.nodes(data=True):
        data['name'] = ATOM_MAP[data['x'].index(1.0)]
        del data['x']
    return g

# %% [markdown]
# ## Sample visualization
#
# We sample a single molecule from train_dataset and visualize it

# %%
import random

data = random.choice([t for t in train_dataset])
mol = to_molecule(data)
plt.figure(figsize=(10, 5))
draw_molecule(mol)

# %% [markdown]
# ## Training the model
#
# In the next section, we train a GNN model with 5 convolution layers. We use GraphConv which supports `edge_weight` as a parameter. Many convolution layers in Pytorch Geometric supoort this argument.

# %% [markdown]
# ### Define the model

# %%
import torch
import torch.nn.functional as F
from torch.nn import Linear

from torch_geometric.nn import global_add_pool, GraphConv

class Net(torch.nn.Module):
    def __init__(self, dim):
        super(Net, self).__init__()

        num_features = dataset.num_features
        self.dim = dim

        self.conv1 = GraphConv(num_features, dim)
        self.conv2 = GraphConv(dim, dim)
        self.conv3 = GraphConv(dim, dim)
        self.conv4 = GraphConv(dim, dim)
        self.conv5 = GraphConv(dim, dim)

        self.fc1 = Linear(dim, dim)
        self.fc2 = Linear(dim, dataset.num_classes)

    def forward(self, x, edge_index, batch, edge_weight=None):
        x = F.relu(self.conv1(x, edge_index, edge_weight))
        x = F.relu(self.conv2(x, edge_index, edge_weight))
        x = F.relu(self.conv3(x, edge_index, edge_weight))
        x = F.relu(self.conv4(x, edge_index, edge_weight))
        x = F.relu(self.conv5(x, edge_index, edge_weight))
        x = global_add_pool(x, batch)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=-1)

# %% [markdown]
# ### Define train and test functions

# %%
def train(epoch):
    model.train()

    if epoch == 51:
        for param_group in optimizer.param_groups:
            param_group['lr'] = 0.5 * param_group['lr']

    loss_all = 0
    for data in train_loader:
        data = data.to(device)
        optimizer.zero_grad()
        output = model(data.x, data.edge_index, data.batch)
        loss = F.nll_loss(output, data.y)
        loss.backward()
        loss_all += loss.item() * data.num_graphs
        optimizer.step()
    return loss_all / len(train_dataset)


def test(loader):
    model.eval()

    correct = 0
    for data in loader:
        data = data.to(device)
        output = model(data.x, data.edge_index, data.batch)
        pred = output.max(dim=1)[1]
        correct += pred.eq(data.y).sum().item()
    return correct / len(loader.dataset)

# %% [markdown]
# ### Train the model for 100 epochs
#
# The accuracy should be around 80% in the end

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = Net(dim=32).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

for epoch in range(1, 101):
    train_loss = train(epoch)
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print('Epoch: {:03d}, Train Loss: {:.7f}, '
          'Train Acc: {:.7f}, Test Acc: {:.7f}'.format(epoch, train_loss,
                                                       train_acc, test_acc))
# Out:
# Epoch: 001, Train Loss: 0.9634822, Train Acc: 0.6654713, Test Acc: 0.6628176
# Epoch: 002, Train Loss: 0.6506687, Train Acc: 0.6518955, Test Acc: 0.6628176
# Epoch: 003, Train Loss: 0.6277030, Train Acc: 0.6857070, Test Acc: 0.6997691
# Epoch: 004, Train Loss: 0.6041665, Train Acc: 0.7095287, Test Acc: 0.7182448
# Epoch: 005, Train Loss: 0.5882458, Train Acc: 0.7149078, Test Acc: 0.7136259
# Epoch: 006, Train Loss: 0.5646879, Train Acc: 0.7366803, Test Acc: 0.7251732
# Epoch: 007, Train Loss: 0.5495455, Train Acc: 0.7538422, Test Acc: 0.7321016
# Epoch: 008, Train Loss: 0.5437595, Train Acc: 0.7597336, Test Acc: 0.7367206
# Epoch: 009, Train Loss: 0.5244001, Train Acc: 0.7653689, Test Acc: 0.7598152
# Epoch: 010, Train Loss: 0.5214222, Train Acc: 0.7679303, Test Acc: 0.7644342
# Epoch: 011, Train Loss: 0.5110950, Train Acc: 0.7745902, Test Acc: 0.7736721
# Epoch: 012, Train Loss: 0.5083530, Train Acc: 0.7781762, Test Acc: 0.7713626
# Epoch: 013, Train Loss: 0.5173480, Train Acc: 0.7743340, Test Acc: 0.7644342
# Epoch: 014, Train Loss: 0.5016141, Train Acc: 0.7797131, Test Acc: 0.7575058
# Epoch: 015, Train Loss: 0.4956553, Train Acc: 0.7820184, Test Acc: 0.7713626
# Epoch: 016, Train Loss: 0.4847021, Train Acc: 0.7861168, Test Acc: 0.7667436
# Epoch: 017, Train Loss: 0.4838806, Train Acc: 0.7927766, Test Acc: 0.7736721
# Epoch: 018, Train Loss: 0.4791179, Train Acc: 0.7907275, Test Acc: 0.7759815
# Epoch: 019, Train Loss: 0.4713055, Train Acc: 0.7938012, Test Acc: 0.7759815
# Epoch: 020, Train Loss: 0.4628161, Train Acc: 0.8009734, Test Acc: 0.7782910
# Epoch: 021, Train Loss: 0.4626275, Train Acc: 0.8101947, Test Acc: 0.7806005
# Epoch: 022, Train Loss: 0.4598599, Train Acc: 0.8002049, Test Acc: 0.7875289
# Epoch: 023, Train Loss: 0.4572817, Train Acc: 0.8012295, Test Acc: 0.7944573
# Epoch: 024, Train Loss: 0.4484231, Train Acc: 0.8145492, Test Acc: 0.8175520
# Epoch: 025, Train Loss: 0.4407582, Train Acc: 0.8114754, Test Acc: 0.7990762
# Epoch: 026, Train Loss: 0.4383784, Train Acc: 0.8137807, Test Acc: 0.8060046
# Epoch: 027, Train Loss: 0.4317866, Train Acc: 0.8181352, Test Acc: 0.8060046
# Epoch: 028, Train Loss: 0.4270025, Train Acc: 0.8219775, Test Acc: 0.8106236
# Epoch: 029, Train Loss: 0.4271562, Train Acc: 0.8240266, Test Acc: 0.8060046
# Epoch: 030, Train Loss: 0.4214228, Train Acc: 0.8240266, Test Acc: 0.8036952
# Epoch: 031, Train Loss: 0.4238789, Train Acc: 0.8237705, Test Acc: 0.8036952
# Epoch: 032, Train Loss: 0.4125470, Train Acc: 0.8281250, Test Acc: 0.8129330
# Epoch: 033, Train Loss: 0.4185125, Train Acc: 0.8317111, Test Acc: 0.8106236
# Epoch: 034, Train Loss: 0.4075145, Train Acc: 0.8335041, Test Acc: 0.8129330
# Epoch: 035, Train Loss: 0.4061791, Train Acc: 0.8345287, Test Acc: 0.8267898
# Epoch: 036, Train Loss: 0.4009690, Train Acc: 0.8370902, Test Acc: 0.8360277
# Epoch: 037, Train Loss: 0.3861440, Train Acc: 0.8447746, Test Acc: 0.8429561
# Epoch: 038, Train Loss: 0.3891069, Train Acc: 0.8381148, Test Acc: 0.8314088
# Epoch: 039, Train Loss: 0.3895032, Train Acc: 0.8383709, Test Acc: 0.8290993
# Epoch: 040, Train Loss: 0.3871989, Train Acc: 0.8440061, Test Acc: 0.8429561
# Epoch: 041, Train Loss: 0.3736332, Train Acc: 0.8493852, Test Acc: 0.8406467
# Epoch: 042, Train Loss: 0.3683531, Train Acc: 0.8478484, Test Acc: 0.8244804
# Epoch: 043, Train Loss: 0.3904200, Train Acc: 0.8450307, Test Acc: 0.8452656
# Epoch: 044, Train Loss: 0.3749513, Train Acc: 0.8460553, Test Acc: 0.8383372
# Epoch: 045, Train Loss: 0.3718905, Train Acc: 0.8529713, Test Acc: 0.8290993
# Epoch: 046, Train Loss: 0.3673170, Train Acc: 0.8588627, Test Acc: 0.8314088
# Epoch: 047, Train Loss: 0.3702122, Train Acc: 0.8434939, Test Acc: 0.8152425
# Epoch: 048, Train Loss: 0.3750213, Train Acc: 0.8370902, Test Acc: 0.8106236
# Epoch: 049, Train Loss: 0.3664722, Train Acc: 0.8271004, Test Acc: 0.8036952
# Epoch: 050, Train Loss: 0.3670218, Train Acc: 0.8411885, Test Acc: 0.8129330
# Epoch: 051, Train Loss: 0.3523584, Train Acc: 0.8609119, Test Acc: 0.8337182
# Epoch: 052, Train Loss: 0.3389340, Train Acc: 0.8693648, Test Acc: 0.8290993
# Epoch: 053, Train Loss: 0.3284329, Train Acc: 0.8734631, Test Acc: 0.8406467
# Epoch: 054, Train Loss: 0.3317369, Train Acc: 0.8673156, Test Acc: 0.8337182
# Epoch: 055, Train Loss: 0.3295653, Train Acc: 0.8709016, Test Acc: 0.8360277
# Epoch: 056, Train Loss: 0.3291904, Train Acc: 0.8678279, Test Acc: 0.8221709
# Epoch: 057, Train Loss: 0.3224640, Train Acc: 0.8714139, Test Acc: 0.8360277
# Epoch: 058, Train Loss: 0.3228647, Train Acc: 0.8711578, Test Acc: 0.8244804
# Epoch: 059, Train Loss: 0.3184423, Train Acc: 0.8750000, Test Acc: 0.8337182
# Epoch: 060, Train Loss: 0.3155948, Train Acc: 0.8721824, Test Acc: 0.8290993
# Epoch: 061, Train Loss: 0.3174254, Train Acc: 0.8647541, Test Acc: 0.8198614
# Epoch: 062, Train Loss: 0.3211585, Train Acc: 0.8678279, Test Acc: 0.8198614
# Epoch: 063, Train Loss: 0.3204417, Train Acc: 0.8752561, Test Acc: 0.8337182
# Epoch: 064, Train Loss: 0.3130700, Train Acc: 0.8778176, Test Acc: 0.8337182
# Epoch: 065, Train Loss: 0.3170359, Train Acc: 0.8737193, Test Acc: 0.8152425
# Epoch: 066, Train Loss: 0.3130165, Train Acc: 0.8675717, Test Acc: 0.8083141
# Epoch: 067, Train Loss: 0.3141412, Train Acc: 0.8683402, Test Acc: 0.8198614
# Epoch: 068, Train Loss: 0.3114708, Train Acc: 0.8742316, Test Acc: 0.8244804
# Epoch: 069, Train Loss: 0.3067974, Train Acc: 0.8793545, Test Acc: 0.8244804
# Epoch: 070, Train Loss: 0.3017724, Train Acc: 0.8811475, Test Acc: 0.8267898
# Epoch: 071, Train Loss: 0.2971715, Train Acc: 0.8775615, Test Acc: 0.8290993
# Epoch: 072, Train Loss: 0.3087640, Train Acc: 0.8670594, Test Acc: 0.8036952
# Epoch: 073, Train Loss: 0.2993443, Train Acc: 0.8778176, Test Acc: 0.8244804
# Epoch: 074, Train Loss: 0.3048139, Train Acc: 0.8785861, Test Acc: 0.8083141
# Epoch: 075, Train Loss: 0.2979162, Train Acc: 0.8770492, Test Acc: 0.8129330
# Epoch: 076, Train Loss: 0.3056238, Train Acc: 0.8885758, Test Acc: 0.8360277
# Epoch: 077, Train Loss: 0.2928733, Train Acc: 0.8883197, Test Acc: 0.8406467
# Epoch: 078, Train Loss: 0.2926157, Train Acc: 0.8906250, Test Acc: 0.8337182
# Epoch: 079, Train Loss: 0.2889609, Train Acc: 0.8852459, Test Acc: 0.8314088
# Epoch: 080, Train Loss: 0.2892565, Train Acc: 0.8872951, Test Acc: 0.8175520
# Epoch: 081, Train Loss: 0.2865767, Train Acc: 0.8893443, Test Acc: 0.8244804
# Epoch: 082, Train Loss: 0.2910864, Train Acc: 0.8908811, Test Acc: 0.8406467
# Epoch: 083, Train Loss: 0.2849013, Train Acc: 0.8857582, Test Acc: 0.8198614
# Epoch: 084, Train Loss: 0.2903056, Train Acc: 0.8857582, Test Acc: 0.8152425
# Epoch: 085, Train Loss: 0.2857187, Train Acc: 0.8860143, Test Acc: 0.8083141
# Epoch: 086, Train Loss: 0.2902431, Train Acc: 0.8844775, Test Acc: 0.8175520
# Epoch: 087, Train Loss: 0.2869679, Train Acc: 0.8844775, Test Acc: 0.8129330
# Epoch: 088, Train Loss: 0.2850525, Train Acc: 0.8888320, Test Acc: 0.8129330
# Epoch: 089, Train Loss: 0.2845149, Train Acc: 0.8844775, Test Acc: 0.8036952
# Epoch: 090, Train Loss: 0.2773664, Train Acc: 0.8916496, Test Acc: 0.8267898
# Epoch: 091, Train Loss: 0.2834637, Train Acc: 0.8916496, Test Acc: 0.8267898
# Epoch: 092, Train Loss: 0.2750560, Train Acc: 0.8965164, Test Acc: 0.8360277
# Epoch: 093, Train Loss: 0.2746884, Train Acc: 0.8949795, Test Acc: 0.8290993
# Epoch: 094, Train Loss: 0.2718037, Train Acc: 0.8988217, Test Acc: 0.8383372
# Epoch: 095, Train Loss: 0.2745689, Train Acc: 0.8983094, Test Acc: 0.8360277
# Epoch: 096, Train Loss: 0.2847354, Train Acc: 0.8919057, Test Acc: 0.8290993
# Epoch: 097, Train Loss: 0.2754233, Train Acc: 0.8849898, Test Acc: 0.7990762
# Epoch: 098, Train Loss: 0.2760751, Train Acc: 0.8821721, Test Acc: 0.8013857
# Epoch: 099, Train Loss: 0.2771369, Train Acc: 0.8783299, Test Acc: 0.7944573
# Epoch: 100, Train Loss: 0.2793561, Train Acc: 0.8698770, Test Acc: 0.7967667

# %% [markdown]
# ## Explaining the predictions
#
# Now we look at two popular attribution methods. First, we calculate the gradient of the output with respect to the edge weights $w_{e_i}$. Edge weights are initially one for all edges.
# For the saliency method, we use the absolute value of the gradient as the attribution value for each edge:
#
# $$
# Attribution_{e_i} = |\frac{\partial F(x)}{\partial w_{e_i}}|
# $$
#
# Where $x$ is the input and $F(x)$ is the output of the GNN model on input $x$.
#
# For Integrated Gradients method, we interpolate between the current input and a baseline input where the weight of all edges is zero and accumulate the gradient values for each edge:
#
# $$
# Attribution_{e_i} = \int_{\alpha =0}^1 \frac{\partial F(x_{\alpha)}}{\partial w_{e_i}} d\alpha
# $$
#
# Where $x_{\alpha}$ is the same as the original input graph but the weight of all edges is set to $\alpha$. Integrated Gradients complete formulation is more complicated but since our initial edge weights are equal to one and the baseline is zero, it can be simplified to the formulation above. You can read more about this method [here](https://arxiv.org/abs/1703.01365). Of course, this can not be calculated directly and is approximated by a discrete sum.
#
# We use the [captum](https://captum.ai/) library for calculating the attribution values. We define the `model_forward` function which calculates the `batch` argument assuming that we are only explaining a single graph at a time.

# %%
from captum.attr import Saliency, IntegratedGradients

def model_forward(edge_mask, data):
    batch = torch.zeros(data.x.shape[0], dtype=int).to(device)
    out = model(data.x, data.edge_index, batch, edge_mask)
    return out


def explain(method, data, target=0):
    input_mask = torch.ones(data.edge_index.shape[1]).requires_grad_(True).to(device)
    if method == 'ig':
        ig = IntegratedGradients(model_forward)
        mask = ig.attribute(input_mask, target=target,
                            additional_forward_args=(data,),
                            internal_batch_size=data.edge_index.shape[1])
    elif method == 'saliency':
        saliency = Saliency(model_forward)
        mask = saliency.attribute(input_mask, target=target,
                                  additional_forward_args=(data,))
    else:
        raise Exception('Unknown explanation method')

    edge_mask = np.abs(mask.cpu().detach().numpy())
    if edge_mask.max() > 0:  # avoid division by zero
        edge_mask = edge_mask / edge_mask.max()
    return edge_mask

# %% [markdown]
# Finally we take a random sample from the test dataset and run the explanation methods. For a simpler visualization, we make the graph undirected and merge the explanations of each edge in both directions.
#
# It is known that NO2 substructure makes the molecules mutagenic in many cases and you can verify this by the model explanations.
#
# Mutagenic molecules have label 0 in this dataset and we only sample from those molecules but you can change the code and see the explanations for the other class as well.
#
# In this visualization, edge colors and thickness represent the importance. You can also see the numeric value by passing `draw_edge_labels` to `draw_molecule` function.
#
# As you can see Integrated Gradients tend to create more accurate explanations.

# %%
import random
from collections import defaultdict

def aggregate_edge_directions(edge_mask, data):
    edge_mask_dict = defaultdict(float)
    for val, u, v in list(zip(edge_mask, *data.edge_index)):
        u, v = u.item(), v.item()
        if u > v:
            u, v = v, u
        edge_mask_dict[(u, v)] += val
    return edge_mask_dict
    

data = random.choice([t for t in test_dataset if not t.y.item()])
mol = to_molecule(data)

for title, method in [('Integrated Gradients', 'ig'), ('Saliency', 'saliency')]:
    edge_mask = explain(method, data, target=0)
    edge_mask_dict = aggregate_edge_directions(edge_mask, data)
    plt.figure(figsize=(10, 5))
    plt.title(title)
    draw_molecule(mol, edge_mask_dict)
