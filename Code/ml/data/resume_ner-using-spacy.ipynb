# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as ply
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/resume-entities-for-ner/Entity Recognition in Resumes.json

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
import pandas as pd
df = pd.read_json (r'/kaggle/input/resume-entities-for-ner/Entity Recognition in Resumes.json',lines=True)
df.to_csv (r'dataframe.csv', index = None)

# %%
df
# Out:
#                                                content  \
# 0    Abhishek Jha\nApplication Development Associat...
# 1    Afreen Jamadar\nActive member of IIIT Committe...
# 2    Akhil Yadav Polemaina\nHyderabad, Telangana - ...
# 3    Alok Khandai\nOperational Analyst (SQL DBA) En...
# 4    Ananya Chavan\nlecturer - oracle tutorials\n\n...
# ..                                                 ...
# 215  Mansi Thanki\nStudent\n\nJamnagar, Gujarat - E...
# 216  Anil Kumar\nMicrosoft Azure (Basic Management)...
# 217  Siddharth Choudhary\nMicrosoft Office Suite - ...
# 218  Valarmathi Dhandapani\nInvestment Banking Oper...
# 219  Pradeep Kumar\nSecurity Analyst in Infosys - C...
#
#                                             annotation  extras
# 0    [{'label': ['Skills'], 'points': [{'start': 12...     NaN
# 1    [{'label': ['Email Address'], 'points': [{'sta...     NaN
# 2    [{'label': ['Skills'], 'points': [{'start': 37...     NaN
# 3    [{'label': ['Skills'], 'points': [{'start': 80...     NaN
# 4    [{'label': ['Degree'], 'points': [{'start': 20...     NaN
# ..                                                 ...     ...
# 215  [{'label': ['College Name'], 'points': [{'star...     NaN
# 216  [{'label': ['Location'], 'points': [{'start': ...     NaN
# 217  [{'label': ['Skills'], 'points': [{'start': 78...     NaN
# 218  [{'label': ['Skills'], 'points': [{'start': 92...     NaN
# 219  [{'label': ['Skills'], 'points': [{'start': 58...     NaN
#
# [220 rows x 3 columns]

# %%
df['content'][20]
# Out:
# 'Govardhana K\nSenior Software Engineer\n\nBengaluru, Karnataka, Karnataka - Email me on Indeed: indeed.com/r/Govardhana-K/\nb2de315d95905b68\n\nTotal IT experience 5 Years 6 Months\nCloud Lending Solutions INC 4 Month • Salesforce Developer\nOracle 5 Years 2 Month • Core Java Developer\nLanguages Core Java, Go Lang\nOracle PL-SQL programming,\nSales Force Developer with APEX.\n\nDesignations & Promotions\n\nWilling to relocate: Anywhere\n\nWORK EXPERIENCE\n\nSenior Software Engineer\n\nCloud Lending Solutions -  Bangalore, Karnataka -\n\nJanuary 2018 to Present\n\nPresent\n\nSenior Consultant\n\nOracle -  Bangalore, Karnataka -\n\nNovember 2016 to December 2017\n\nStaff Consultant\n\nOracle -  Bangalore, Karnataka -\n\nJanuary 2014 to October 2016\n\nAssociate Consultant\n\nOracle -  Bangalore, Karnataka -\n\nNovember 2012 to December 2013\n\nEDUCATION\n\nB.E in Computer Science Engineering\n\nAdithya Institute of Technology -  Tamil Nadu\n\nSeptember 2008 to June 2012\n\nhttps://www.indeed.com/r/Govardhana-K/b2de315d95905b68?isid=rex-download&ikw=download-top&co=IN\nhttps://www.indeed.com/r/Govardhana-K/b2de315d95905b68?isid=rex-download&ikw=download-top&co=IN\n\n\nSKILLS\n\nAPEX. (Less than 1 year), Data Structures (3 years), FLEXCUBE (5 years), Oracle (5 years),\nAlgorithms (3 years)\n\nLINKS\n\nhttps://www.linkedin.com/in/govardhana-k-61024944/\n\nADDITIONAL INFORMATION\n\nTechnical Proficiency:\n\nLanguages: Core Java, Go Lang, Data Structures & Algorithms, Oracle\nPL-SQL programming, Sales Force with APEX.\nTools: RADTool, Jdeveloper, NetBeans, Eclipse, SQL developer,\nPL/SQL Developer, WinSCP, Putty\nWeb Technologies: JavaScript, XML, HTML, Webservice\n\nOperating Systems: Linux, Windows\nVersion control system SVN & Git-Hub\nDatabases: Oracle\nMiddleware: Web logic, OC4J\nProduct FLEXCUBE: Oracle FLEXCUBE Versions 10.x, 11.x and 12.x\n\nhttps://www.linkedin.com/in/govardhana-k-61024944/'

# %%
from nltk.corpus import stopwords
import re
from nltk.stem import WordNetLemmatizer
clean=[]

# %%
for i in range(0,220):
    review = re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?"', ' ', df['content'][i])
    review = review.lower()
    review = review.split()
    lm= WordNetLemmatizer() 
    review = [lm.lemmatize(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    clean.append(review)

# %%
df['content'][0]
# Out:
# "Abhishek Jha\nApplication Development Associate - Accenture\n\nBengaluru, Karnataka - Email me on Indeed: indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a\n\n• To work for an organization which provides me the opportunity to improve my skills\nand knowledge for my individual and company's growth in best possible ways.\n\nWilling to relocate to: Bangalore, Karnataka\n\nWORK EXPERIENCE\n\nApplication Development Associate\n\nAccenture -\n\nNovember 2017 to Present\n\nRole: Currently working on Chat-bot. Developing Backend Oracle PeopleSoft Queries\nfor the Bot which will be triggered based on given input. Also, Training the bot for different possible\nutterances (Both positive and negative), which will be given as\ninput by the user.\n\nEDUCATION\n\nB.E in Information science and engineering\n\nB.v.b college of engineering and technology -  Hubli, Karnataka\n\nAugust 2013 to June 2017\n\n12th in Mathematics\n\nWoodbine modern school\n\nApril 2011 to March 2013\n\n10th\n\nKendriya Vidyalaya\n\nApril 2001 to March 2011\n\nSKILLS\n\nC (Less than 1 year), Database (Less than 1 year), Database Management (Less than 1 year),\nDatabase Management System (Less than 1 year), Java (Less than 1 year)\n\nADDITIONAL INFORMATION\n\nTechnical Skills\n\nhttps://www.indeed.com/r/Abhishek-Jha/10e7a8cb732bc43a?isid=rex-download&ikw=download-top&co=IN\n\n\n• Programming language: C, C++, Java\n• Oracle PeopleSoft\n• Internet Of Things\n• Machine Learning\n• Database Management System\n• Computer Networks\n• Operating System worked on: Linux, Windows, Mac\n\nNon - Technical Skills\n\n• Honest and Hard-Working\n• Tolerant and Flexible to Different Situations\n• Polite and Calm\n• Team-Player"

# %%
clean[0]
# Out:
# 'abhishek jha application development associate accenture bengaluru karnataka email indeed indeed com r abhishek jha 10e7a8cb732bc43a work organization provides opportunity improve skill knowledge individual company growth best possible way willing relocate bangalore karnataka work experience application development associate accenture november 2017 present role currently working chat bot developing backend oracle peoplesoft query bot triggered based given input also training bot different possible utterance positive negative given input user education b e information science engineering b v b college engineering technology hubli karnataka august 2013 june 2017 12th mathematics woodbine modern school april 2011 march 2013 10th kendriya vidyalaya april 2001 march 2011 skill c le 1 year database le 1 year database management le 1 year database management system le 1 year java le 1 year additional information technical skill programming language c c java oracle peoplesoft internet thing machine learning database management system computer network operating system worked linux window mac non technical skill honest hard working tolerant flexible different situation polite calm team player'

# %%
df['cleaned']=clean

# %%
df.head()
# Out:
#                                              content  \
# 0  Abhishek Jha\nApplication Development Associat...
# 1  Afreen Jamadar\nActive member of IIIT Committe...
# 2  Akhil Yadav Polemaina\nHyderabad, Telangana - ...
# 3  Alok Khandai\nOperational Analyst (SQL DBA) En...
# 4  Ananya Chavan\nlecturer - oracle tutorials\n\n...
#
#                                           annotation  extras  \
# 0  [{'label': ['Skills'], 'points': [{'start': 12...     NaN
# 1  [{'label': ['Email Address'], 'points': [{'sta...     NaN
# 2  [{'label': ['Skills'], 'points': [{'start': 37...     NaN
# 3  [{'label': ['Skills'], 'points': [{'start': 80...     NaN
# 4  [{'label': ['Degree'], 'points': [{'start': 20...     NaN
#
#                                              cleaned
# 0  abhishek jha application development associate...
# 1  afreen jamadar active member iiit committee th...
# 2  akhil yadav polemaina hyderabad telangana emai...
# 3  alok khandai operational analyst sql dba engin...
# 4  ananya chavan lecturer oracle tutorial mumbai ...

# %% [markdown]
# # Using NLTK Library of Part of Speech

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /opt/conda/lib/python3.7/site-packages (2.2.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy) (3.0.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from spacy) (0.6.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /opt/conda/lib/python3.7/site-packages (from spacy) (1.0.0)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /opt/conda/lib/python3.7/site-packages (from spacy) (0.9.6)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from spacy) (2.0.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from spacy) (46.1.3.post20200325)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /opt/conda/lib/python3.7/site-packages (from spacy) (0.4.1)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /opt/conda/lib/python3.7/site-packages (from spacy) (7.3.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.7/site-packages (from spacy) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.7/site-packages (from spacy) (2.23.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.7/site-packages (from spacy) (1.18.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /opt/conda/lib/python3.7/site-packages (from spacy) (1.0.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from catalogue<1.1.0,>=0.0.7->spacy) (1.6.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /opt/conda/lib/python3.7/site-packages (from thinc<7.4.0,>=7.3.0->spacy) (4.45.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy

# %%
nlp = spacy.load("en")

# %%
# def pos(sent):
#     se=nlp(sent)
#     for word in se:
#         print(word,word.pos_)

# %%
# pos(df['cleaned'][0])

# %%
from spacy.lang.en import English
# Load English tokenizer, tagger, parser, NER and word vectors
nlp = English()

text = df['cleaned'][100]

my_doc = nlp(text)

# %%
# Create list of word tokens
token_list = []
for token in my_doc:
    token_list.append(token.text)
print(token_list)
# Out:
# ['yasothai', 'jayaramachandran', 'lead', 'engineer', 'automation', 'testing', 'chennai', 'tamil', 'nadu', 'email', 'indeed', 'indeed', 'com', 'r', 'yasothai', 'jayaramachandran', 'c36e76b64d9f477f', '4', 'year', 'experience', 'testing', 'methodology', 'automation', 'regression', 'sanity', 'manual', 'hand', 'experience', 'selenium', 'webdriver', 'python', 'automation', 'skilled', 'ide', 'pycharm', 'eclipse', 'pydev', 'plugin', 'selenium', 'testing', 'web', 'browser', 'using', 'python', 'expertise', 'developing', 'automation', 'script', 'testing', 'various', 'component', 'skilled', 'providing', 'effective', 'quality', 'automation', 'process', 'hand', 'experience', 'functional', 'automation', 'script', 'using', 'tcl', 'programming', 'python', 'experienced', 'planning', 'designing', 'developing', 'deploying', 'testing', 'strategy', 'trained', 'worked', 'closely', 'along', 'developer', 'dev', 'test', 'manual', 'engineer', 'automation', 'task', 'good', 'experience', 'reviewing', 'automated', 'tcl', 'python', 'script', 'developed', 'team', 'member', 'extracting', 'data', 'excel', 'csv', 'file', 'posting', 'result', 'excel', 'file', 'python', 'experience', 'agile', 'development', 'played', 'responsible', 'role', 'scrum', 'master', 'automation', 'work', 'experience', 'lead', 'engineer', 'automation', 'testing', 'cisco', 'system', 'january', '2014', 'june', '2015', 'duration', 'jan', '2014', 'jun', '2015', 'team', 'size', '20', 'role', 'responsibility', 'lead', 'engineer', 'automation', 'testing', 'identified', 'case', 'giving', 'support', 'waas', 'product', 'v6', 'addressing', 'test', 'plan', 'played', 'active', 'role', 'scrum', 'master', 'automation', 'activity', 'participated', 'organized', 'automation', 'team', 'work', 'agile', 'methodology', 'prepared', 'hld', 'document', 'automatable', 'case', 'automated', 'around', '1000', 'case', 'snmp', 'platform', 'module', 'automated', 'basic', 'sanity', 'test', 'case', 'executing', 'sanity', 'testing', 'v6', 'support', 'involved', 'regressing', 'automated', 'suite', 'performed', 'regression', 'automated', 'case', 'at', 'framework', 'aetest', 'script', 'template', 'reviewed', 'automated', 'case', 'developed', 'team', 'member', 'regression', 'testing', 'defect', 'filing', 'cdets', 'rally', 'worked', 'agile', 'development', 'methodology', 'language', 'tcl', 'programming', 'python', 'selenium', 'release', 'hornet', 'description', 'ipv6', 'formerly', 'named', 'ipng', 'next', 'generation', 'latest', 'version', 'internet', 'protocol', 'ip', 'ip', 'packet', 'based', 'protocol', 'used', 'exchange', 'data', 'voice', 'video', 'traffic', 'digital', 'network', 'cisco', 'wide', 'area', 'application', 'service', 'ipv4', 'user', 'move', 'ipv6', 'receive', 'service', 'end', 'end', 'security', 'quality', 'service', 'qos', 'globally', 'unique', 'address', 'ipv6', 'address', 'space', 'reduces', 'need', 'private', 'address', 'network', 'address', 'translation', 'nat', 'processing', 'border', 'router', 'network', 'edge', 'implementing', 'basic', 'ipv6', 'connectivity', 'cisco', 'io', 'software', 'consists', 'assigning', 'ipv6', 'address', 'individual', 'router', 'interface', 'forwarding', 'ipv6', 'traffic', 'enabled', 'globally', 'cisco', 'express', 'forwarding', 'switching', 'ipv6', 'also', 'enabled', 'primary', 'motivation', 'ipv6', 'need', 'meet', 'demand', 'globally', 'unique', 'ip', 'address', 'mainly', 'involves', 'check', 'functionality', 'waas', 'feature', 'work', 'v6', 'addressing', 'product', 'ipv6', 'support', 'waas', 'wide', 'area', 'application', 'service', 'project', 'cisco', 'waas', 'express', 'wexp', 'member', 'technical', 'staff', 'automation', 'testing', 'cisco', 'system', 'january', '2013', 'december', '2013', 'duration', 'jan', '2013', 'december', '2013', 'team', 'size', '21', 'role', 'responsibility', 'member', 'technical', 'staff', 'automation', 'testing', 'identified', 'automatable', 'case', 'test', 'plan', 'prepared', 'hld', 'document', 'automatable', 'case', 'automated', 'test', 'case', ' ...

# %%
# sent_list=[]
# for token in my_doc.sents:
#     sent_list.append(token.text)
# print(sent_list)

# %%
import en_core_web_sm

# load en_core_web_sm of English for vocabluary, syntax & entities
nlp = en_core_web_sm.load()

#  "nlp" Objectis used to create documents with linguistic annotations.
docs = nlp(df['cleaned'][100])

# %%
for word in docs:
    print(word.text,word.pos_)
# Out:
# yasothai PROPN
# jayaramachandran PROPN
# lead PROPN
# engineer PROPN
# automation PROPN
# testing PROPN
# chennai PROPN
# tamil PROPN
# nadu PROPN
# email NOUN
# indeed ADV
# indeed ADV
# com PROPN
# r DET
# yasothai PROPN
# jayaramachandran PROPN
# c36e76b64d9f477f VERB
# 4 NUM
# year NOUN
# experience NOUN
# testing NOUN
# methodology NOUN
# automation NOUN
# regression NOUN
# sanity NOUN
# manual ADJ
# hand NOUN
# experience NOUN
# selenium NOUN
# webdriver PROPN
# python PROPN
# automation NOUN
# skilled VERB
# ide PROPN
# pycharm PROPN
# eclipse PROPN
# pydev PROPN
# plugin ADJ
# selenium NOUN
# testing NOUN
# web NOUN
# browser NOUN
# using VERB
# python PROPN
# expertise NOUN
# developing VERB
# automation NOUN
# script NOUN
# testing NOUN
# various ADJ
# component NOUN
# skilled ADJ
# providing VERB
# effective ADJ
# quality NOUN
# automation NOUN
# process NOUN
# hand NOUN
# experience NOUN
# functional ADJ
# automation NOUN
# script NOUN
# using VERB
# tcl PROPN
# programming PROPN
# python PROPN
# experienced VERB
# planning NOUN
# designing VERB
# developing VERB
# deploying VERB
# testing NOUN
# strategy NOUN
# trained VERB
# worked VERB
# closely ADV
# along ADP
# developer NOUN
# dev PROPN
# test PROPN
# manual PROPN
# engineer NOUN
# automation NOUN
# task NOUN
# good ADJ
# experience NOUN
# reviewing VERB
# automated VERB
# tcl PROPN
# python PROPN
# script PROPN
# developed VERB
# team NOUN
# member NOUN
# extracting PROPN
# data PROPN
# excel VERB
# csv NOUN
# file NOUN
# posting VERB
# result NOUN
# excel PROPN
# file NOUN
# python PROPN
# experience PROPN
# agile PROPN
# development NOUN
# played VERB
# responsible ADJ
# role NOUN
# scrum PROPN
# master NOUN
# automation NOUN
# work NOUN
# experience NOUN
# lead NOUN
# engineer NOUN
# automation NOUN
# testing PROPN
# cisco PROPN
# system NOUN
# january PROPN
# 2014 NUM
# june PROPN
# 2015 NUM
# duration PROPN
# jan PROPN
# 2014 NUM
# jun PROPN
# 2015 NUM
# team NOUN
# size NOUN
# 20 NUM
# role NOUN
# responsibility NOUN
# lead NOUN
# engineer NOUN
# automation NOUN
# testing NOUN
# identified VERB
# case NOUN
# giving VERB
# support NOUN
# waas PROPN
# product NOUN
# v6 NOUN
# addressing VERB
# test NOUN
# plan NOUN
# played VERB
# active ADJ
# role NOUN
# scrum NOUN
# master NOUN
# automation NOUN
# activity NOUN
# participated VERB
# organized VERB
# automation NOUN
# team NOUN
# work VERB
# agile NOUN
# methodology NOUN
# prepared VERB
# hld PROPN
# document NOUN
# automatable ADJ
# case NOUN
# automated VERB
# around ADP
# 1000 NUM
# case NOUN
# snmp ADJ
# platform NOUN
# module NOUN
# automated VERB
# basic ADJ
# sanity NOUN
# test NOUN
# case NOUN
# executing VERB
# sanity NOUN
# testing NOUN
# v6 PROPN
# support NOUN
# involved VERB
# regressing VERB
# automated VERB
# suite PROPN
# performed VERB
# regression NOUN
# automated VERB
# case NOUN
# at ADP
# framework PROPN
# aetest ADJ
# script NOUN
# template NOUN
# reviewed VERB
# automated VERB
# case NOUN
# developed VERB
# team NOUN
# member NOUN
# regression NOUN
# testing NOUN
# defect NOUN
# filing VERB
# cdets NOUN
# rally NOUN
# worked VERB
# agile ADJ
# development NOUN
# methodology PROPN
# language NOUN
# tcl PROPN
# programming VERB
# python PROPN
# selenium PROPN
# release PROPN
# hornet NOUN
# description NOUN
# ipv6 PROPN
# formerly ADV
# named VERB
# ipng PROPN
# next ADJ
# generation NOUN
# latest ADJ
# version NOUN
# internet NOUN
# protocol PROPN
# ip PROPN
# ip PROPN
# packet PROPN
# based VERB
# protocol PROPN
# used VERB
# exchange PROPN
# data PROPN
# voice NOUN
# video NOUN
# traffic NOUN
# digital PROPN
# network NOUN
# cisco PROPN
# wide ADJ
# area NOUN
# application NOUN
# service PROPN
# ipv4 PROPN
# user NOUN
# move PROPN
# ipv6 PROPN
# receive VERB
# service NOUN
# end NOUN
# end NOUN
# security NOUN
# quality NOUN
# service NOUN
# qos NOUN
# globally ADV
# unique ADJ
# address NOUN
# ipv6 PROPN
# address NOUN
# space NOUN
# reduces NOUN
# need VERB
# private ADJ
# address NOUN
# network NOUN
# address NOUN
# translation PROPN
# nat PROPN
# processing VERB
# border NOUN
# router NOUN
# network NOUN
# edge NOUN
# implementing VERB
# basic PROPN
# ipv6 PROPN
# connectivity PROPN
# cisco PROPN
# io PROPN
# software NOUN
# consists VERB
# assigning VERB
# ipv6 PROPN
# address NOUN
# individual ADJ
# router NOUN
# interface NOUN
# forwarding VERB
# ipv6 PROPN
# traffic NOUN
# enabled VERB
# globally ADV
# cisco PROPN
# express PROPN
# forwarding VERB
# switching NOUN
# ipv6 PROPN
# also ADV
# enabled VERB
# primary ADJ
# motivation NOUN
# ipv6 PROPN
# need VERB
# meet VERB
# demand NOUN
# globally ADV
# unique ADJ
# ip NOUN
# address NOUN
# mainly ADV
# involves VERB
# check NOUN
# functionality NOUN
# waas PROPN
# feature NOUN
# work NOUN
# v6 PROPN
# addressing VERB
# product NOUN
# ipv6 PROPN
# support NOUN
# waas PROPN
# wide ADJ
# area NOUN
# application NOUN
# service NOUN
# project PROPN
# cisco PROPN
# waas PROPN
# express PROPN
# wexp PROPN
# member PROPN
# technical PROPN
# staff PROPN
# automation NOUN
# testing PROPN
# cisco PROPN
# system NOUN
# january PROPN
# 2013 NUM
# december PROPN
# 2013 NUM
# duration NOUN
# jan PROPN
# 2013 NUM
# december PROPN
# 2013 NUM
# team NOUN
# size NOUN
# 21 NUM
# role NOUN
# responsibility NOUN
# member NOUN
# technical PROPN
# staff NOUN
# automation NOUN
# testing NOUN
# identified VERB
# automatable ADJ
# case NOUN
# test NOUN
# plan NOUN
# prepared VERB
# hld PROPN
# document NOUN
# automatable ADJ
# case NOUN
# automated VERB
# test NOUN
# case NOUN
# various ADJ
# component NOUN
# wexp NOUN
# product NOUN
# functionality NOUN
# check NOUN
# worked VERB
# config NOUN
# sync NOUN
# http VERB
# http ADJ
# ssl PROPN
# smb PROPN
# ao PROPN
# component PROPN
# automation NOUN
# automated VERB
# around ADP
# 200 NUM
# case NOUN
# various ADJ
# component NOUN
# performed VERB
# regression NOUN
# automated VERB
# case NOUN
# at ADP
# framework PROPN
# aetest ADJ
# script NOUN
# template NOUN
# reviewed VERB
# automated VERB
# case NOUN
# developed VERB
# team NOUN
# member NOUN
# involved VERB
# executing VERB
# automated VERB
# case NOUN
# various ADJ
# release NOUN
# phase1 NOUN
# phase2 NOUN
# pi19 PROPN
# 25 NUM
# posted VERB
# result NOUN
# tims NOUN
# tool NOUN
# regression NOUN
# testing NOUN
# defect NOUN
# filing VERB
# cdets NOUN
# language NOUN
# tcl PROPN
# programming VERB
# python PROPN
# release PROPN
# phase1 NOUN
# phase2 NOUN
# 535 NUM
# description NOUN
# cisco PROPN
# wide ADJ
# area NOUN
# application NOUN
# service NOUN
# waas PROPN
# express VERB
# feature NOUN
# key ADJ
# component PROPN
# cisco PROPN
# waas PROPN
# product PROPN
# portfolio NOUN
# waas PROPN
# express VERB
# cost NOUN
# effective ADJ
# io ADP
# based VERB
# wan PROPN
# optimization NOUN
# solution NOUN
# increase NOUN
# amount NOUN
# available ADJ
# bandwidth ADJ
# small ADJ
# mid ADJ
# size PROPN
# branch NOUN
# office PROPN
# remote PROPN
# location PROPN
# accelerating VERB
# tcp PROPN
# based VERB
# application NOUN
# operate VERB
# wan PROPN
# environment PROPN
# wide ADJ
# area NOUN
# application NOUN
# service NOUN
# waas PROPN
# express ADJ
# software NOUN
# optimizes VERB
# tcp PROPN
# traffic NOUN
# flow NOUN
# across ADP
# wan PROPN
# waas PROPN
# express PROPN
# integrates VERB
# native ADJ
# service PROPN
# security PROPN
# netflow PROPN
# quality PROPN
# service PROPN
# qos PROPN
# waas PROPN
# express PROPN
# provides VERB
# following VERB
# benefit NOUN
# bandwidth NOUN
# optimization NOUN
# application NOUN
# acceleration NOUN
# increase NOUN
# remote ADJ
# user NOUN
# productivity NOUN
# interoperation NOUN
# existing VERB
# cisco PROPN
# waas PROPN
# infrastructure NOUN
# network NOUN
# transparency NOUN
# deployment NOUN
# flexibility NOUN
# demand NOUN
# service NOUN
# enablement NOUN
# wexp ADJ
# wide ADJ
# area NOUN
# application NOUN
# service NOUN
# io ADP
# router NOUN
# mainly ADV
# involves VERB
# check NOUN
# functionality NOUN
# optimizing VERB
# various ADJ
# ao NOUN
# like INTJ
# http NOUN
# ssl NOUN
# http PROPN
# smb PROPN
# config NOUN
# sync NOUN
# product NOUN
# waas PROPN
# express VERB
# wide ADJ
# area NOUN
# application NOUN
# service NOUN
# project PROPN
# cisco PROPN
# waas PROPN
# client PROPN
# cisco PROPN
# system PROPN
# organisation PROPN
# hcl PROPN
# technology PROPN
# ltd PROPN
# software PROPN
# engineer PROPN
# automation PROPN
# testing PROPN
# june PROPN
# 2011 NUM
# december PROPN
# 2012 NUM
# identified VERB
# automatable ADJ
# case NOUN
# test NOUN
# plan NOUN
# prepared VERB
# hld PROPN
# document NOUN
# automatable ADJ
# case NOUN
# automated VERB
# test NOUN
# case NOUN
# various ADJ
# component NOUN
# waas PROPN
# product NOUN
# functionality NOUN
# check NOUN
# worked VERB
# plaform NOUN
# snmp NOUN
# ssl NOUN
# http PROPN
# component NOUN
# automation NOUN
# automated VERB
# around ADP
# 600 NUM
# case NOUN
# various ADJ
# component NOUN
# performed VERB
# regression NOUN
# automated VERB
# case NOUN
# at ADP
# framework PROPN
# aetest ADJ
# script NOUN
# template NOUN
# active ADJ
# participation NOUN
# automating VERB
# test NOUN
# case NOUN
# sanity PROPN
# test NOUN
# reviewed VERB
# automated VERB
# case NOUN
# developed VERB
# team NOUN
# member NOUN
# involved VERB
# executing VERB
# automated VERB
# case NOUN
# reporting NOUN
# bug NOUN
# defect NOUN
# worked VERB
# various ADJ
# release NOUN
# product NOUN
# lancer NOUN
# phoenix PROPN
# skyhawk PROPN
# regressing VERB
# automated VERB
# case NOUN
# posted VERB
# result NOUN
# tims NOUN
# tool NOUN
# defect VERB
# filing VERB
# cdets NOUN
# language NOUN
# tcl PROPN
# programming VERB
# python PROPN
# release PROPN
# lancer PROPN
# phoenix PROPN
# skyhawk PROPN
# sprit PROPN
# description NOUN
# wide ADJ
# area NOUN
# application NOUN
# service NOUN
# waas PROPN
# cisco PROPN
# system NOUN
# technology NOUN
# improves VERB
# performance NOUN
# application NOUN
# wide ADJ
# area NOUN
# network PROPN
# wan PROPN
# waas PROPN
# combine VERB
# cisco PROPN
# wide ADJ
# area NOUN
# file NOUN
# service NOUN
# wafs NOUN
# product NOUN
# allow VERB
# remote ADJ
# office NOUN
# user NOUN
# access NOUN
# share NOUN
# file NOUN
# globally ADV
# lan PROPN
# speed PROPN
# wan PROPN
# wan PROPN
# optimization PROPN
# inside ADP
# router NOUN
# accelerating VERB
# tcp NOUN
# based VERB
# application NOUN
# given VERB
# network NOUN
# waas PROPN
# system NOUN
# consists VERB
# set VERB
# device NOUN
# called VERB
# wide ADJ
# area NOUN
# application NOUN
# engine NOUN
# waes VERB
# work NOUN
# together ADV
# optimize VERB
# tcp PROPN
# traffic NOUN
# network NOUN
# client NOUN
# server NOUN
# application NOUN
# attempt NOUN
# communicate NOUN
# network NOUN
# intercept PROPN
# redirects VERB
# traffic NOUN
# waes PROPN
# act PROPN
# behalf NOUN
# client NOUN
# application NOUN
# destination NOUN
# server NOUN
# waes VERB
# examine VERB
# traffic NOUN
# use NOUN
# built VERB
# application NOUN
# policy NOUN
# determine NOUN
# whether SCONJ
# optimize NOUN
# traffic NOUN
# allow VERB
# pas PROPN
# network PROPN
# un PROPN
# optimized VERB
# mainly ADV
# involves VERB
# optimizing VERB
# various ADJ
# ao NOUN
# like INTJ
# http ADJ
# ssl NOUN
# http ADJ
# functional ADJ
# wise ADJ
# platform NOUN
# check NOUN
# product NOUN
# waas NOUN
# wide ADJ
# area NOUN
# application NOUN
# service NOUN
# education NOUN
# b PROPN
# e PROPN
# cse PROPN
# anna PROPN
# university PROPN
# 2011 NUM
# day NOUN
# adventist PROPN
# matric PROPN
# hr PROPN
# sec PROPN
# school PROPN
# 2005 NUM
# 2007 NUM
# skill NOUN
# optimization NOUN
# 2 NUM
# year NOUN
# python PROPN
# 4 NUM
# year NOUN
# router PROPN
# 4 NUM
# year NOUN
# tcl PROPN
# 4 NUM
# year NOUN
# testing VERB
# 4 NUM
# year NOUN
# additional ADJ
# information NOUN
# technical ADJ
# skill NOUN
# programming NOUN
# language PROPN
# python PROPN
# tcl PROPN
# power PROPN
# query PROPN
# sql PROPN
# shell PROPN
# scripting VERB
# c PROPN
# concept NOUN
# networking NOUN
# waas PROPN
# wan PROPN
# optimization NOUN
# waas PROPN
# router PROPN
# wae VERB
# wide ADJ
# area NOUN
# engine NOUN
# wccp PROPN
# protocol PROPN
# automation NOUN
# framework NOUN
# at ADP
# automated VERB
# test NOUN
# system NOUN
# selenium NOUN
# testing VERB
# framework NOUN
# ide PROPN
# integrated VERB
# development PROPN
# environment PROPN
# eclipse PROPN
# pycharm PROPN
# pydev PROPN
# plugin PROPN
# eclipse PROPN
# ide PROPN
# software PROPN
# eclipse PROPN
# cdets PROPN
# rally PROPN
# bug NOUN
# tracking NOUN
# earms NOUN
# regression NOUN
# testing NOUN
# acme PROPN
# versioning VERB
# tims PROPN
# reporting VERB
# htmltestrunner NOUN
# power PROPN
# query PROPN
# automation PROPN
# ara PROPN
# plm PROPN
# product PROPN
# lifecycle PROPN
# management PROPN
# aml PROPN
# studio PROPN
# adaptive PROPN
# markup PROPN
# language NOUN
# operating NOUN
# system NOUN
# window NOUN
# xp PROPN
# 10 NUM
# linux PROPN

# %%
from spacy import displacy

nytimes= nlp(df['cleaned'][100])

entities=[(i, i.label_, i.label) for i in nytimes.ents]
entities
# Out:
# [(yasothai jayaramachandran, 'PERSON', 380),
#  (yasothai jayaramachandran, 'PERSON', 380),
#  (4 year, 'DATE', 391),
#  (ide pycharm, 'ORG', 383),
#  (python, 'ORG', 383),
#  (tcl programming python, 'ORG', 383),
#  (tcl python, 'ORG', 383),
#  (excel csv file, 'ORG', 383),
#  (python, 'GPE', 384),
#  (scrum, 'PRODUCT', 386),
#  (cisco, 'GPE', 384),
#  (january 2014 june 2015, 'DATE', 391),
#  (jun 2015, 'LAW', 390),
#  (20, 'CARDINAL', 397),
#  (v6, 'PRODUCT', 386),
#  (1000, 'CARDINAL', 397),
#  (v6, 'CARDINAL', 397),
#  (tcl programming, 'ORG', 383),
#  (digital, 'ORG', 383),
#  (cisco, 'GPE', 384),
#  (qos, 'ORG', 383),
#  (cisco, 'GPE', 384),
#  (cisco express, 'ORG', 383),
#  (v6, 'PRODUCT', 386),
#  (cisco waas express, 'ORG', 383),
#  (cisco, 'GPE', 384),
#  (january 2013 december 2013, 'DATE', 391),
#  (december 2013, 'DATE', 391),
#  (21, 'CARDINAL', 397),
#  (200, 'CARDINAL', 397),
#  (535, 'CARDINAL', 397),
#  (waas express, 'ORG', 383),
#  (cisco waas, 'FAC', 9191306739292312949),
#  (waas express, 'ORG', 383),
#  (wan, 'PERSON', 380),
#  (mid size branch office, 'ORG', 383),
#  (wan, 'ORG', 383),
#  (waas express, 'ORG', 383),
#  (wan waas express, 'ORG', 383),
#  (qos waas express, 'ORG', 383),
#  (cisco waas, 'ORG', 383),
#  (waas express, 'ORG', 383),
#  (cisco waas, 'PERSON', 380),
#  (cisco system organisation hcl technology ltd, 'ORG', 383),
#  (june 2011 december 2012, 'DATE', 391),
#  (600, 'CARDINAL', 397),
#  (phoenix skyhawk, 'ORG', 383),
#  (tcl programming, 'ORG', 383),
#  (phoenix skyhawk, 'ORG', 383),
#  (waas cisco system technology improves, 'ORG', 383),
#  (area network, 'ORG', 383),
#  (wan waas combine, 'PRODUCT', 386),
#  (cisco wide, 'PERSON', 380),
#  (lan speed, 'PERSON', 380),
#  (wan wan, 'PERSON', 380),
#  (un, 'ORG', 383),
#  (2011 day, 'DATE', 391),
#  (sec, 'ORG', 383),
#  (2005, 'DATE', 391),
#  (2007, 'DATE', 391),
#  (2 year, 'DATE', 391),
#  (4 year, 'DATE', 391),
#  (4 year tcl 4 year, 'DATE', 391),
#  (4 year, 'DATE', 391),
#  (python tcl, 'ORG', 383),
#  (query sql, 'PERSON', 380),
#  (wccp protocol, 'PRODUCT', 386),
#  (pycharm, 'GPE', 384),
#  (ide, 'ORG', 383),
#  (10 linux, 'MONEY', 394)]

# %%
displacy.render(nytimes, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yasothai jayaramachandran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  lead engineer automation testing chennai tamil nadu email indeed indeed com r
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     yasothai jayaramachandran
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  c36e76b64d9f477f
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4 year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  experience testing methodology automation regression sanity manual hand experience selenium webdriver python automation skilled
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ide pycharm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  eclipse pydev plugin selenium testing web browser using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  expertise developing automation script testing various component skilled providing effective quality automation process hand experience functional automation script using
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tcl programming python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  experienced planning designing developing deploying testing strategy trained worked closely along developer dev test manual engineer automation task good experience reviewing automated
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tcl python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  script developed team member extracting data
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     excel csv file
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  posting result excel file
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     python
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  experience agile development played responsible role
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     scrum
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  master automation work experience lead engineer automation testing
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cisco
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  system
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     january 2014 june 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  duration jan 2014
# <mark class="entity" style="background: #ff8197; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     jun 2015
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">LAW</span>
# </mark>
#  team size
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  role responsibility lead engineer automation testing identified case giving support waas product
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     v6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  addressing test plan played active role scrum master automation activity participated organized automation team work agile methodology prepared hld document automatable case automated around
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  case snmp platform module automated basic sanity test case executing sanity testing
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     v6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  support involved regressing automated suite performed regression automated case at framework aetest script template reviewed automated case developed team member regression testing defect filing cdets rally worked agile development methodology language
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tcl programming
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  python selenium release hornet description ipv6 formerly named ipng next generation latest version internet protocol ip ip packet based protocol used exchange data voice video traffic
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     digital
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transfor

# %% [markdown]
# # Mostly words are recognised correctly.
